# %%
import pandas as pd

df = pd.read_csv('rus_pipeline.csv')
df
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0             1                 29                     0  0.0005         3
# 1             1                 29                     0  0.0005         3
# 2             1                 29                     0  0.0005         3
# 3             1                 29                     0  0.0005         5
# 4             1                 29                     0  0.0005         5
# ..          ...                ...                   ...     ...       ...
# 101           1                 29                     0  0.0002        10
# 102           1                 29                     0  0.0002        10
# 103           1                 29                     0  0.0002        10
# 104           1                 29                     0  0.0002        10
# 105           1                 29                     0  0.0002        10
#
#      use_rus  rus_seed  undersample_rate  sensitivity  specificity  accuracy  \
# 0       True         0               0.1       0.5470       0.9831    0.9605
# 1       True         1               0.1       0.5470       0.9801    0.9577
# 2       True         2               0.1       0.5805       0.9780    0.9575
# 3       True         0               0.1       0.5279       0.9847    0.9610
# 4       True         0               0.1       0.5710       0.9801    0.9589
# ..       ...       ...               ...          ...          ...       ...
# 101     True         0               0.1       0.5120       0.9861    0.9616
# 102     True         1               0.1       0.5391       0.9843    0.9613
# 103     True         2               0.1       0.5199       0.9870    0.9628
# 104     True         3               0.1       0.4960       0.9920    0.9663
# 105     True         4               0.1       0.4577       0.9920    0.9643
#
#      precision     mcc  micro_auroc  train_bce  valid_bce  valid_mcc
# 0       0.6387  0.5706       0.9362     0.0084     0.0747     0.5814
# 1       0.6007  0.5511       0.9254     0.0043     0.0970     0.5983
# 2       0.5909  0.5633       0.9306     0.0147     0.0633     0.5877
# 3       0.6529  0.5671       0.9310     0.0109     0.0725     0.6007
# 4       0.6099  0.5685       0.9286     0.0058     0.1107     0.5816
# ..         ...     ...          ...        ...        ...        ...
# 101     0.6687  0.5657       0.9180     0.0010     0.1167     0.6144
# 102     0.6525  0.5731       0.9153     0.0022     0.1138     0.6167
# 103     0.6863  0.5786       0.9097     0.0012     0.1443     0.6134
# 104     0.7717  0.6028       0.9177     0.0010     0.1293     0.6114
# 105     0.7573  0.5723       0.9289     0.0042     0.1179     0.6070
#
# [106 rows x 17 columns]

# %%
# df['undersample_rate'] = 0.1
# cols = df.columns.tolist()
# cols = cols[:7] + cols[-1:] + cols[7:-1]
# df = df[cols]
# df.to_csv('rus_pipeline.csv')

# %%
df_stat = df.groupby([
    'bce_weight',
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'use_rus',
    'undersample_rate']
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
       'specificity': ['mean', 'std'],
       'accuracy': ['mean', 'std'],
       'sensitivity': ['mean', 'std'],
       'precision': ['mean', 'std'],
    }
    ).reset_index()
df_stat
# Out:
#   bce_weight bert_freeze_layer gearnet_freeze_layer      lr patience use_rus  \
#
# 0          1                29                    0  0.0002       10    True
# 1          1                29                    0  0.0002       10    True
# 2          1                29                    0  0.0005        3    True
# 3          1                29                    0  0.0005        5    True
#
#   undersample_rate       mcc                sensitivity           specificity  \
#                         mean       std size        mean       std        mean
# 0             0.05  0.581130  0.013914   30    0.525630  0.034588    0.986650
# 1             0.10  0.576627  0.016124   15    0.509093  0.032269    0.987713
# 2             0.10  0.557426  0.029873   58    0.529169  0.051275    0.982929
# 3             0.10  0.566900  0.001709    3    0.543867  0.023620    0.982900
#
#              accuracy           precision
#         std      mean       std      mean       std
# 0  0.003205  0.962780  0.001749  0.686713  0.039090
# 1  0.002954  0.962933  0.001806  0.697587  0.043147
# 2  0.005088  0.959434  0.003608  0.635498  0.052208
# 3  0.002458  0.960133  0.001097  0.635433  0.022606
