# %%
import pandas as pd

df = pd.read_csv('rus_pipeline.csv')
df
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer        lr  patience  \
# 0             1                 29                     0  0.000500         3
# 1             1                 29                     0  0.000500         3
# 2             1                 29                     0  0.000500         3
# 3             1                 29                     0  0.000500         5
# 4             1                 29                     0  0.000500         5
# ..          ...                ...                   ...       ...       ...
# 179           1                 29                     0  0.000002        10
# 180           1                 29                     0  0.000002        10
# 181           1                 29                     0  0.000002        10
# 182           1                 29                     0  0.000002        10
# 183           1                 29                     0  0.000002        10
#
# ...

# %%
# df.loc[df['early_stop_metric'] != 'valid_bce', 'early_stop_metric'] = 'valid_mcc'
# df
# df.to_csv('rus_pipeline.csv')

# %%
df_stat = df.groupby([
    'bce_weight',
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'use_rus',
    'undersample_rate',
    'early_stop_metric'
    ]
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
       'specificity': ['mean', 'std'],
       'accuracy': ['mean', 'std'],
       'sensitivity': ['mean', 'std'],
       'precision': ['mean', 'std'],
       'valid_bce': ['mean', 'std'],
    }
    ).reset_index()
df_stat
# Out:
#   bce_weight bert_freeze_layer gearnet_freeze_layer        lr patience  \
#
# 0          1                29                    0  0.000002       10
# 1          1                29                    0  0.000020       10
# 2          1                29                    0  0.000200       10
# 3          1                29                    0  0.000200       10
# 4          1                29                    0  0.000200       10
# 5          1                29                    0  0.000200       10
# 6          1                29                    0  0.000500        3
# 7          1                29                    0  0.000500        5
#
#   use_rus undersample_rate early_stop_metric       mcc            ...  \
#                                                   mean       std  ...
# 0    True             0.05         valid_bce  0.395313  0.016917  ...
# 1    True             0.05         valid_bce  0.407100       NaN  ...
# ...
