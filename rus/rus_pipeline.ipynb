# %%
import pandas as pd

df = pd.read_csv('rus_pipeline.csv')
df
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0             1                 29                     0  0.0005         3
# 1             1                 29                     0  0.0005         3
# 2             1                 29                     0  0.0005         3
# 3             1                 29                     0  0.0005         5
# 4             1                 29                     0  0.0005         5
# ..          ...                ...                   ...     ...       ...
# 235           1                 28                     0  0.0002        10
# 236           1                 28                     0  0.0002        10
# 237           1                 28                     0  0.0002        10
# 238           1                 28                     0  0.0002        10
# 239           1                 28                     0  0.0002        10
#
#      use_rus  rus_seed  undersample_rate  sensitivity  specificity  accuracy  \
# 0       True         0              0.10       0.5470       0.9831    0.9605
# 1       True         1              0.10       0.5470       0.9801    0.9577
# 2       True         2              0.10       0.5805       0.9780    0.9575
# 3       True         0              0.10       0.5279       0.9847    0.9610
# 4       True         0              0.10       0.5710       0.9801    0.9589
# ..       ...       ...               ...          ...          ...       ...
# 235     True        25              0.05       0.5231       0.9859    0.9619
# 236     True        26              0.05       0.5152       0.9877    0.9632
# 237     True        27              0.05       0.5455       0.9861    0.9633
# 238     True        28              0.05       0.5726       0.9842    0.9629
# 239     True        29              0.05       0.6396       0.9683    0.9513
#
#      precision     mcc  micro_auroc  train_bce  valid_bce  valid_mcc  \
# 0       0.6387  0.5706       0.9362     0.0084     0.0747     0.5814
# 1       0.6007  0.5511       0.9254     0.0043     0.0970     0.5983
# 2       0.5909  0.5633       0.9306     0.0147     0.0633     0.5877
# 3       0.6529  0.5671       0.9310     0.0109     0.0725     0.6007
# 4       0.6099  0.5685       0.9286     0.0058     0.1107     0.5816
# ..         ...     ...          ...        ...        ...        ...
# 235     0.6694  0.5724       0.9149     0.0027     0.1064     0.6031
# 236     0.6961  0.5805       0.9089     0.0018     0.0950     0.6173
# 237     0.6826  0.5915       0.9126     0.0044     0.0859     0.5948
# 238     0.6648  0.5977       0.9111     0.0017     0.0927     0.6274
# 239     0.5242  0.5536       0.9185     0.0064     0.0520     0.5755
#
#     early_stop_metric optimizer
# 0           valid_mcc      adam
# 1           valid_mcc      adam
# 2           valid_mcc      adam
# 3           valid_mcc      adam
# 4           valid_mcc      adam
# ..                ...       ...
# 235         valid_mcc     adamw
# 236         valid_mcc     adamw
# 237         valid_mcc     adamw
# 238         valid_mcc     adamw
# 239         valid_mcc     adamw
#
# [240 rows x 19 columns]

# %%
# df.loc[df['optimizer'] != 'adamw', 'optimizer'] = 'adam'
# df
# df.to_csv('rus_pipeline.csv', index=False)

# %%
df_stat = df.groupby([
    'bce_weight',
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'use_rus',
    'undersample_rate',
    'early_stop_metric',
    'optimizer'
    ]
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
    #    'specificity': ['mean', 'std'],
    #    'accuracy': ['mean', 'std'],
       'precision': ['mean', 'std'],
       'valid_mcc': ['mean', 'std'],
    }
    ).reset_index()
df_stat[df_stat['early_stop_metric'] == 'valid_mcc']
# Out:
#   bce_weight bert_freeze_layer gearnet_freeze_layer      lr patience use_rus  \
#
# 0          1                28                    0  0.0002       10    True
# 1          1                28                    0  0.0002       10    True
# 5          1                29                    0  0.0002       10    True
# 6          1                29                    0  0.0002       10    True
# 7          1                29                    0  0.0002       10    True
# 8          1                29                    0  0.0005        3    True
# 9          1                29                    0  0.0005        5    True
#
#   undersample_rate early_stop_metric optimizer       mcc                 \
#                                                     mean       std size
# 0             0.05         valid_mcc      adam  0.591783  0.011484    6
# 1             0.05         valid_mcc     adamw  0.583607  0.015775   30
# 5             0.05         valid_mcc      adam  0.581680  0.014039   60
# 6             0.10         valid_mcc      adam  0.576362  0.015613   16
# 7             0.15         valid_mcc      adam  0.573617  0.021579   30
# 8             0.10         valid_mcc      adam  0.557426  0.029873   58
# 9             0.10         valid_mcc      adam  0.566900  0.001709    3
#
#   sensitivity           precision           valid_mcc
#          mean       std      mean       std      mean       std
# 0    0.573617  0.055733  0.656117  0.055295  0.624933  0.011457
# 1    0.546577  0.040301  0.668517  0.051075  0.619137  0.014996
# 5    0.521482  0.033284  0.692860  0.038257  0.610822  0.010883
# 6    0.509275  0.031184  0.696675  0.041843  0.613956  0.014428
# 7    0.501807  0.040804  0.701180  0.048044  0.612240  0.011048
# 8    0.529169  0.051275  0.635498  0.052208  0.584778  0.029938
# 9    0.543867  0.023620  0.635433  0.022606  0.594133  0.010858
