# %%
import pandas as pd

df = pd.read_csv('rus_pipeline.csv')
df
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0             1                 29                     0  0.0005         3
# 1             1                 29                     0  0.0005         3
# 2             1                 29                     0  0.0005         3
# 3             1                 29                     0  0.0005         5
# 4             1                 29                     0  0.0005         5
# ..          ...                ...                   ...     ...       ...
# 132           1                 29                     0  0.0002        10
# 133           1                 29                     0  0.0002        10
# 134           1                 29                     0  0.0002        10
# 135           1                 29                     0  0.0002        10
# 136           1                 29                     0  0.0002        10
#
#      use_rus  rus_seed  undersample_rate  sensitivity  specificity  accuracy  \
# 0       True         0              0.10       0.5470       0.9831    0.9605
# 1       True         1              0.10       0.5470       0.9801    0.9577
# 2       True         2              0.10       0.5805       0.9780    0.9575
# 3       True         0              0.10       0.5279       0.9847    0.9610
# 4       True         0              0.10       0.5710       0.9801    0.9589
# ..       ...       ...               ...          ...          ...       ...
# 132     True         5              0.15       0.4928       0.9882    0.9625
# 133     True         6              0.15       0.5869       0.9814    0.9609
# 134     True         7              0.15       0.4530       0.9908    0.9629
# 135     True         8              0.15       0.5215       0.9841    0.9602
# 136     True         9              0.15       0.4785       0.9932    0.9665
#
#      precision     mcc  micro_auroc  train_bce  valid_bce  valid_mcc
# 0       0.6387  0.5706       0.9362     0.0084     0.0747     0.5814
# 1       0.6007  0.5511       0.9254     0.0043     0.0970     0.5983
# 2       0.5909  0.5633       0.9306     0.0147     0.0633     0.5877
# 3       0.6529  0.5671       0.9310     0.0109     0.0725     0.6007
# 4       0.6099  0.5685       0.9286     0.0058     0.1107     0.5816
# ..         ...     ...          ...        ...        ...        ...
# 132     0.6944  0.5664       0.9161     0.0011     0.1592     0.5954
# 133     0.6323  0.5887       0.9211     0.0030     0.0967     0.6021
# 134     0.7282  0.5569       0.9087     0.0028     0.1171     0.6010
# 135     0.6424  0.5584       0.9209     0.0049     0.0908     0.5919
# 136     0.7937  0.6010       0.9216     0.0012     0.1652     0.6325
#
# [137 rows x 17 columns]

# %%
# df['undersample_rate'] = 0.1
# cols = df.columns.tolist()
# cols = cols[:7] + cols[-1:] + cols[7:-1]
# df = df[cols]
# df.to_csv('rus_pipeline.csv')

# %%
df_stat = df.groupby([
    'bce_weight',
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'use_rus',
    'undersample_rate']
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
       'specificity': ['mean', 'std'],
       'accuracy': ['mean', 'std'],
       'sensitivity': ['mean', 'std'],
       'precision': ['mean', 'std'],
    }
    ).reset_index()
df_stat
# Out:
#   bce_weight bert_freeze_layer gearnet_freeze_layer      lr patience use_rus  \
#
# 0          1                29                    0  0.0002       10    True
# 1          1                29                    0  0.0002       10    True
# 2          1                29                    0  0.0002       10    True
# 3          1                29                    0  0.0005        3    True
# 4          1                29                    0  0.0005        5    True
#
#   undersample_rate       mcc                sensitivity           specificity  \
#                         mean       std size        mean       std        mean
# 0             0.05  0.581130  0.013914   30    0.525630  0.034588    0.986650
# 1             0.10  0.576362  0.015613   16    0.509275  0.031184    0.987669
# 2             0.15  0.573617  0.021579   30    0.501807  0.040804    0.988010
# 3             0.10  0.557426  0.029873   58    0.529169  0.051275    0.982929
# 4             0.10  0.566900  0.001709    3    0.543867  0.023620    0.982900
#
#              accuracy           precision
#         std      mean       std      mean       std
# 0  0.003205  0.962780  0.001749  0.686713  0.039090
# 1  0.002860  0.962900  0.001750  0.696675  0.041843
# 2  0.003547  0.962820  0.002311  0.701180  0.048044
# 3  0.005088  0.959434  0.003608  0.635498  0.052208
# 4  0.002458  0.960133  0.001097  0.635433  0.022606
