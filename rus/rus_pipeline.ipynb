# %%
import pandas as pd

df_raw = pd.read_csv('rus_pipeline.csv')
df_raw
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0             1                 29                     0  0.0005         3
# 1             1                 29                     0  0.0005         3
# 2             1                 29                     0  0.0005         3
# 3             1                 29                     0  0.0005         5
# 4             1                 29                     0  0.0005         5
# ..          ...                ...                   ...     ...       ...
# 247           1                 27                     0  0.0002        10
# 248           1                 27                     0  0.0002        10
# 249           1                 27                     0  0.0002        10
# 250           1                 27                     0  0.0002        10
# 251           1                 27                     0  0.0002        10
#
# ...

# %%
# df.loc[df['optimizer'] != 'adamw', 'optimizer'] = 'adam'
# df
# df.to_csv('rus_pipeline.csv', index=False)

# %%
df = df_raw[(df_raw['optimizer'] == 'adam') | (df_raw.index >= 240)]
df
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0             1                 29                     0  0.0005         3
# 1             1                 29                     0  0.0005         3
# 2             1                 29                     0  0.0005         3
# 3             1                 29                     0  0.0005         5
# 4             1                 29                     0  0.0005         5
# ..          ...                ...                   ...     ...       ...
# 247           1                 27                     0  0.0002        10
# 248           1                 27                     0  0.0002        10
# 249           1                 27                     0  0.0002        10
# 250           1                 27                     0  0.0002        10
# 251           1                 27                     0  0.0002        10
#
# ...

# %%
df_stat = df.groupby([
    'bce_weight',
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'use_rus',
    'undersample_rate',
    'early_stop_metric',
    'optimizer'
    ]
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
    #    'specificity': ['mean', 'std'],
    #    'accuracy': ['mean', 'std'],
       'precision': ['mean', 'std'],
       'valid_mcc': ['mean', 'std'],
    }
    ).reset_index()
df_stat[df_stat['early_stop_metric'] == 'valid_mcc']
# Out:
#    bce_weight bert_freeze_layer gearnet_freeze_layer      lr patience use_rus  \
#
# 0           1                27                    0  0.0002       10    True
# 1           1                28                    0  0.0002       10    True
# 2           1                28                    0  0.0002       10    True
# 6           1                29                    0  0.0002       10    True
# 7           1                29                    0  0.0002       10    True
# 8           1                29                    0  0.0002       10    True
# 9           1                29                    0  0.0005        3    True
# 10          1                29                    0  0.0005        5    True
#
#    undersample_rate early_stop_metric optimizer       mcc                 \
#                                                      mean       std size
# 0              0.05         valid_mcc      adam  0.586040  0.009630   10
# ...
