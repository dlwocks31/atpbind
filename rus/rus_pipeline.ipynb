# %%
import pandas as pd

df = pd.read_csv('rus_pipeline_v2.csv')
df
# Out:
#      Unnamed: 0  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0           0.0                 28                     0  0.0001        10
# 1           1.0                 28                     0  0.0002        10
# 2           2.0                 28                     0  0.0004        10
# 3           3.0                 28                     0  0.0008        10
# 4           4.0                 29                     0  0.0001        10
# ..          ...                ...                   ...     ...       ...
# 299         NaN                 28                     0  0.0004        10
# 300         NaN                 28                     0  0.0004        10
# 301         NaN                 28                     0  0.0004        10
# 302         NaN                 28                     0  0.0004        10
# 303         NaN                 28                     0  0.0004        10
#
#      rus_seed  undersample_rate early_stop_metric optimizer  lr_half_epoch  \
# 0           0              0.05         valid_mcc      adam              0
# 1           0              0.05         valid_mcc      adam              0
# 2           0              0.05         valid_mcc      adam              0
# 3           0              0.05         valid_mcc      adam              0
# 4           0              0.05         valid_mcc      adam              0
# ..        ...               ...               ...       ...            ...
# 299        44              0.05         valid_mcc      adam             12
# 300        45              0.05         valid_mcc      adam             12
# 301        46              0.05         valid_mcc      adam             12
# 302        47              0.05         valid_mcc      adam             12
# 303        48              0.05         valid_mcc      adam             12
#
#      sensitivity  specificity  accuracy  precision     mcc  micro_auroc  \
# 0         0.5885       0.9786    0.9584     0.6000  0.5723       0.9083
# 1         0.5423       0.9854    0.9624     0.6693  0.5832       0.9127
# 2         0.5885       0.9801    0.9598     0.6171  0.5815       0.9036
# 3         0.5853       0.9784    0.9580     0.5967  0.5689       0.9122
# 4         0.5582       0.9775    0.9558     0.5757  0.5436       0.9121
# ..           ...          ...       ...        ...     ...          ...
# 299       0.5375       0.9877    0.9644     0.7050  0.5976       0.8982
# 300       0.4306       0.9943    0.9651     0.8036  0.5732       0.8966
# 301       0.4896       0.9895    0.9636     0.7173  0.5749       0.9087
# 302       0.4976       0.9892    0.9637     0.7156  0.5790       0.8970
# 303       0.5152       0.9900    0.9654     0.7374  0.5995       0.9014
#
#      train_bce  valid_bce  valid_mcc  epoch_count
# 0       0.0037     0.1476     0.5543           22
# 1       0.0035     0.1517     0.5872           25
# 2       0.0013     0.2043     0.5811           33
# 3       0.0030     0.1974     0.5570           28
# 4       0.0028     0.1555     0.5452           25
# ..         ...        ...        ...          ...
# 299     0.0005     0.1851     0.5963           32
# 300     0.0010     0.2057     0.5942           31
# 301     0.0007     0.1901     0.5988           34
# 302     0.0007     0.1891     0.5989           35
# 303     0.0013     0.1699     0.5940           30
#
# [304 rows x 20 columns]

# %%
# def add_constant_column(df, column_name, constant_value, position=None):
#     """
#     Add a new column with a constant value to a DataFrame at a specified position.

#     Parameters:
#     - df: The DataFrame
#     - column_name: Name of the new column
#     - constant_value: The constant value to populate the new column with
#     - position: The position (index) at which the new column should be inserted. 
#                 If not specified, the column will be added at the end.

#     Returns:
#     - DataFrame with the added column
#     """
#     if position is None:
#         df[column_name] = constant_value
#     else:
#         df.insert(position, column_name, constant_value)
#     return df


# df2 = add_constant_column(df, 'lr_half_epoch', 0, position=8)
# df2.to_csv('rus_pipeline_v2.csv')

# %%
df_stat = df.groupby([
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'undersample_rate',
    'early_stop_metric',
    'optimizer',
    'lr_half_epoch',
    ]
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
    #    'specificity': ['mean', 'std'],
    #    'accuracy': ['mean', 'std'],
       'precision': ['mean', 'std'],
       'valid_mcc': ['mean', 'std'],
       'epoch_count': ['mean', 'std'],
    }
    ).reset_index()

df_stat
# Out:
#   bert_freeze_layer gearnet_freeze_layer      lr patience undersample_rate  \
#
# 0                28                    0  0.0001       10             0.05
# 1                28                    0  0.0002       10             0.05
# 2                28                    0  0.0004       10             0.05
# 3                28                    0  0.0004       10             0.05
# 4                28                    0  0.0004       10             0.10
# 5                28                    0  0.0008       10             0.05
# 6                29                    0  0.0001       10             0.05
# 7                29                    0  0.0002       10             0.05
# 8                29                    0  0.0004       10             0.05
# 9                29                    0  0.0008       10             0.05
#
#   early_stop_metric optimizer lr_half_epoch       mcc                 \
#                                                  mean       std size
# 0         valid_mcc      adam             0  0.561167  0.021041    6
# 1         valid_mcc      adam             0  0.577887  0.016491  100
# 2         valid_mcc      adam             0  0.573539  0.016940  100
# 3         valid_mcc      adam            12  0.583543  0.012788   49
# 4         valid_mcc      adam            12  0.578305  0.012358   20
# 5         valid_mcc      adam             0  0.538767  0.025650    6
# 6         valid_mcc      adam             0  0.550750  0.017223    6
# 7         valid_mcc      adam             0  0.570767  0.006785    6
# 8         valid_mcc      adam             0  0.567533  0.010703    6
# 9         valid_mcc      adam             0  0.566160  0.014240    5
#
#   sensitivity           precision           valid_mcc           epoch_count  \
#          mean       std      mean       std      mean       std        mean
# 0    0.525517  0.037677  0.647383  0.068664  0.573400  0.010891   30.166667
# 1    0.533381  0.054919  0.675305  0.069786  0.590001  0.008917   31.780000
# 2    0.547544  0.064881  0.652833  0.080072  0.583509  0.008946   31.210000
# 3    0.489639  0.044786  0.741112  0.053530  0.597194  0.007398   34.489796
# 4    0.466900  0.048726  0.762820  0.056003  0.601375  0.006110   32.500000
# 5    0.559267  0.036045  0.568467  0.056140  0.552767  0.008069   28.833333
# 6    0.494700  0.074165  0.672217  0.114220  0.554567  0.015847   39.333333
# 7    0.500533  0.037203  0.696333  0.043253  0.571183  0.009731   39.166667
# 8    0.561133  0.057313  0.622983  0.063521  0.578167  0.007692   35.333333
# 9    0.514180  0.036957  0.670220  0.058501  0.570680  0.005535   40.600000
#
#
#          std
# 0   6.675827
# 1   8.929103
# 2   7.458024
# 3   5.852786
# 4   7.030011
# 5   6.177918
# 6  12.940891
# 7   9.196014
# 8  11.003030
# 9  11.013628

# %%
df_old = pd.read_csv('rus_pipeline.csv')
df_old
# Out:
#      bce_weight  bert_freeze_layer  gearnet_freeze_layer      lr  patience  \
# 0             1                 29                     0  0.0005         3
# 1             1                 29                     0  0.0005         3
# 2             1                 29                     0  0.0005         3
# 3             1                 29                     0  0.0005         5
# 4             1                 29                     0  0.0005         5
# ..          ...                ...                   ...     ...       ...
# 247           1                 27                     0  0.0002        10
# 248           1                 27                     0  0.0002        10
# 249           1                 27                     0  0.0002        10
# 250           1                 27                     0  0.0002        10
# 251           1                 27                     0  0.0002        10
#
#      use_rus  rus_seed  undersample_rate  sensitivity  specificity  accuracy  \
# 0       True         0              0.10       0.5470       0.9831    0.9605
# 1       True         1              0.10       0.5470       0.9801    0.9577
# 2       True         2              0.10       0.5805       0.9780    0.9575
# 3       True         0              0.10       0.5279       0.9847    0.9610
# 4       True         0              0.10       0.5710       0.9801    0.9589
# ..       ...       ...               ...          ...          ...       ...
# 247     True        25              0.05       0.5439       0.9865    0.9636
# 248     True        26              0.05       0.5263       0.9850    0.9613
# 249     True        27              0.05       0.5853       0.9813    0.9608
# 250     True        28              0.05       0.5279       0.9863    0.9626
# 251     True        29              0.05       0.5726       0.9820    0.9608
#
#      precision     mcc  micro_auroc  train_bce  valid_bce  valid_mcc  \
# 0       0.6387  0.5706       0.9362     0.0084     0.0747     0.5814
# 1       0.6007  0.5511       0.9254     0.0043     0.0970     0.5983
# 2       0.5909  0.5633       0.9306     0.0147     0.0633     0.5877
# 3       0.6529  0.5671       0.9310     0.0109     0.0725     0.6007
# 4       0.6099  0.5685       0.9286     0.0058     0.1107     0.5816
# ..         ...     ...          ...        ...        ...        ...
# 247     0.6875  0.5929       0.9073     0.0009     0.1229     0.6278
# 248     0.6574  0.5684       0.9125     0.0016     0.1039     0.6044
# 249     0.6306  0.5869       0.9205     0.0022     0.0871     0.6130
# 250     0.6783  0.5794       0.9109     0.0014     0.1010     0.6144
# 251     0.6343  0.5821       0.9132     0.0011     0.0978     0.6077
#
#     early_stop_metric optimizer
# 0           valid_mcc      adam
# 1           valid_mcc      adam
# 2           valid_mcc      adam
# 3           valid_mcc      adam
# 4           valid_mcc      adam
# ..                ...       ...
# 247         valid_mcc      adam
# 248         valid_mcc      adam
# 249         valid_mcc      adam
# 250         valid_mcc      adam
# 251         valid_mcc      adam
#
# [252 rows x 19 columns]

# %%
df_stat_old = df_old.groupby([
    'bert_freeze_layer',
    'gearnet_freeze_layer',
    'lr',
    'patience',
    'undersample_rate',
    'early_stop_metric',
    'optimizer',
    ]
).agg({'mcc': ['mean', 'std', 'size'],
       'sensitivity': ['mean', 'std'],
    #    'specificity': ['mean', 'std'],
    #    'accuracy': ['mean', 'std'],
       'precision': ['mean', 'std'],
       'valid_mcc': ['mean', 'std'],
    }
    ).reset_index()
df_stat_old
# Out:
#    bert_freeze_layer gearnet_freeze_layer        lr patience undersample_rate  \
#
# 0                 27                    0  0.000200       10             0.05
# 1                 28                    0  0.000200       10             0.05
# 2                 28                    0  0.000200       10             0.05
# 3                 29                    0  0.000002       10             0.05
# 4                 29                    0  0.000020       10             0.05
# 5                 29                    0  0.000200       10             0.05
# 6                 29                    0  0.000200       10             0.05
# 7                 29                    0  0.000200       10             0.10
# 8                 29                    0  0.000200       10             0.15
# 9                 29                    0  0.000500        3             0.10
# 10                29                    0  0.000500        5             0.10
#
#    early_stop_metric optimizer       mcc                sensitivity            \
#                                     mean       std size        mean       std
# 0          valid_mcc      adam  0.586040  0.009630   10    0.559020  0.031476
# 1          valid_mcc      adam  0.591783  0.011484    6    0.573617  0.055733
# 2          valid_mcc     adamw  0.584025  0.015477   32    0.547553  0.040838
# 3          valid_bce      adam  0.395313  0.016917   15    0.781500  0.024439
# 4          valid_bce      adam  0.407100       NaN    1    0.757600       NaN
# 5          valid_bce      adam  0.410000       NaN    1    0.783100       NaN
# 6          valid_mcc      adam  0.581680  0.014039   60    0.521482  0.033284
# 7          valid_mcc      adam  0.576362  0.015613   16    0.509275  0.031184
# 8          valid_mcc      adam  0.573617  0.021579   30    0.501807  0.040804
# 9          valid_mcc      adam  0.557426  0.029873   58    0.529169  0.051275
# 10         valid_mcc      adam  0.566900  0.001709    3    0.543867  0.023620
#
#    precision           valid_mcc
#         mean       std      mean       std
# 0   0.657680  0.029405  0.614410  0.012464
# 1   0.656117  0.055295  0.624933  0.011457
# 2   0.668238  0.050172  0.619116  0.014544
# 3   0.252980  0.021846  0.459840  0.012748
# 4   0.271100       NaN  0.494600       NaN
# 5   0.266000       NaN  0.470500       NaN
# 6   0.692860  0.038257  0.610822  0.010883
# 7   0.696675  0.041843  0.613956  0.014428
# 8   0.701180  0.048044  0.612240  0.011048
# 9   0.635498  0.052208  0.584778  0.029938
# 10  0.635433  0.022606  0.594133  0.010858
