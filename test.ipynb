# %%
import pandas as pd

df = pd.read_csv('result_cv/esm-33-gearnet-ensemble/fold_0/intermediate/agg_record.csv')

# %%
df
# Out:
#                   model_key  valid_fold  iter  sensitivity  specificity  \
# 0   esm-33-gearnet-ensemble           0     0       0.6443       0.9849
# 1   esm-33-gearnet-ensemble           0     1       0.6252       0.9888
# 2   esm-33-gearnet-ensemble           0     2       0.6316       0.9870
# 3   esm-33-gearnet-ensemble           0     3       0.6220       0.9889
# 4   esm-33-gearnet-ensemble           0     4       0.6029       0.9890
# 5   esm-33-gearnet-ensemble           0     5       0.6268       0.9892
# 6   esm-33-gearnet-ensemble           0     6       0.6156       0.9877
# 7   esm-33-gearnet-ensemble           0     7       0.6236       0.9896
# 8   esm-33-gearnet-ensemble           0     8       0.6124       0.9884
# 9   esm-33-gearnet-ensemble           0     9       0.5885       0.9911
# 10  esm-33-gearnet-ensemble           0    10       0.6236       0.9869
# 11  esm-33-gearnet-ensemble           0    11       0.6140       0.9897
# ...

# %%
df.aggregate({'mcc': ['mean', 'std']})
# Out:
#            mcc
# mean  0.662574
# std   0.009361
