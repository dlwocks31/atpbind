# %%
import pandas as pd

df = pd.read_csv('result_cv/result_cv_sides.csv')

# %%
df
# Out:
#                 model_key  valid_fold  sensitivity  specificity  accuracy  \
# 0      lm-gearnet-lrrange           0       1.0000       0.0010    0.0527
# 1      lm-gearnet-lrrange           0       1.0000       0.0008    0.0525
# 2      lm-gearnet-lrrange           0       1.0000       0.0008    0.0525
# 3      lm-gearnet-lrrange           0       1.0000       0.0007    0.0525
# 4      lm-gearnet-lrrange           0       1.0000       0.0008    0.0525
# ..                    ...         ...          ...          ...       ...
# 557  lm-gearnet-2-lrrange           0       0.0000       1.0000    0.9482
# 558  lm-gearnet-2-lrrange           0       0.0000       1.0000    0.9482
# 559  lm-gearnet-2-lrrange           0       0.0000       0.9998    0.9480
# 560  lm-gearnet-2-lrrange           0       0.0813       0.9941    0.9468
# 561  lm-gearnet-2-lrrange           0       0.9856       0.0774    0.1244
#
#      precision     mcc  micro_auroc  valid_mcc  train_bce   valid_bce  \
# 0       0.0518  0.0070       0.3409     0.0069     0.6747      0.6741
# 1       0.0518  0.0064       0.3408     0.0059     0.6727      0.6723
# 2       0.0518  0.0064       0.3421     0.0062     0.6696      0.6684
# 3       0.0518  0.0060       0.3455     0.0059     0.6647      0.6664
# 4       0.0518  0.0064       0.3539     0.0060     0.6569      0.6587
# ..         ...     ...          ...        ...        ...         ...
# 557        NaN  0.0000       0.3042     0.0000    92.2909  14369.3249
# 558        NaN  0.0000       0.3463     0.0000    84.2686    775.9456
# 559     0.0000 -0.0030       0.4237     0.0000     6.8607     31.4401
# 560     0.4286  0.1694       0.5048     0.1551     0.5946      0.7730
# 561     0.0551  0.0533       0.5040     0.0554     0.3029      0.3330
#
#                lr          finished_at
# 0    1.600000e-08  2023-11-05 22:32:28
# 1    2.500000e-08  2023-11-05 22:32:28
# 2    4.000000e-08  2023-11-05 22:32:28
# 3    6.300000e-08  2023-11-05 22:32:28
# 4    1.000000e-07  2023-11-05 22:32:28
# ..            ...                  ...
# 557  1.995262e-01  2023-11-12 19:28:56
# 558  2.238721e-01  2023-11-12 19:28:56
# 559  2.511886e-01  2023-11-12 19:28:56
# 560  2.818383e-01  2023-11-12 19:28:56
# 561  3.162278e-01  2023-11-12 19:28:56
#
# [562 rows x 13 columns]

# %%
VALID_FOLD = 0
ax = df[(df['valid_fold'] == VALID_FOLD) & (df['lr'] <= 1e-1)].plot(x='lr', y=['mcc', 'valid_bce', 'train_bce'], logx=True, ylim=(0, 0.75))


for n in range(-8, 0):
    ax.axvline(10**n, color='gray', linestyle='--', linewidth=0.5)
    
for n in range(0, 8):
    ax.axhline(n/10, color='gray', linestyle='--', linewidth=0.5)

# %%
VALID_FOLD = 1
ax = df[(df['valid_fold'] == VALID_FOLD) & (df['lr'] <= 1e-1)].plot(x='lr', y=['mcc', 'valid_bce', 'train_bce'], logx=True, ylim=(0, 0.75))


for n in range(-8, 0):
    ax.axvline(10**n, color='gray', linestyle='--', linewidth=0.5)
    
for n in range(0, 8):
    ax.axhline(n/10, color='gray', linestyle='--', linewidth=0.5)

# %%
VALID_FOLD = 2
ax = df[(df['valid_fold'] == VALID_FOLD) & (df['lr'] <= 1e-1)].plot(x='lr', y=['mcc', 'valid_bce', 'train_bce'], logx=True, ylim=(0, 0.75))


for n in range(-8, 0):
    ax.axvline(10**n, color='gray', linestyle='--', linewidth=0.5)
    
for n in range(0, 8):
    ax.axhline(n/10, color='gray', linestyle='--', linewidth=0.5)
