# %%
import pandas as pd

df = pd.read_csv('esm_gn_lora_pipeline.csv')
df
# Out:
#                            lm_key  gearnet_layers   r  lora_dropout  \
# 0    facebook/esm2_t33_650M_UR50D               4   8             0
# 1    facebook/esm2_t33_650M_UR50D               4  10             0
# 2    facebook/esm2_t33_650M_UR50D               4   8             0
# 3    facebook/esm2_t33_650M_UR50D               4   4             0
# 4    facebook/esm2_t33_650M_UR50D               4   6             0
# ..                            ...             ...  ..           ...
# 318  facebook/esm2_t33_650M_UR50D               4   8             0
# 319  facebook/esm2_t33_650M_UR50D               1   8             0
# 320  facebook/esm2_t33_650M_UR50D               2   8             0
# 321  facebook/esm2_t33_650M_UR50D               3   8             0
# 322  facebook/esm2_t33_650M_UR50D               4   8             0
#
#     early_stop_metric  train_layer bias  patience     lr  gpu  sensitivity  \
# ...

# %%
df.groupby(['r', 'gearnet_layers', 'train_layer']).agg({'mcc': ['mean', 'std', 'count'], 'valid_mcc': ['mean', 'std'], 'epoch_count': ['mean', 'std']}).sort_values(by=('mcc', 'mean'), ascending=False).head(10)
# Out:
#                                   mcc                 valid_mcc            \
#                                  mean       std count      mean       std
# r gearnet_layers train_layer
# 4 1              4            0.64685  0.002758     2   0.64650  0.003960
# 8 1              4            0.64180  0.002687     2   0.66040  0.004243
# 6 2              4            0.64140  0.007071     2   0.65160  0.007495
# 8 2              2            0.64070  0.005798     2   0.64725  0.005586
# 6 3              4            0.64015  0.022698     2   0.64885  0.001768
# 4 1              5            0.63964  0.003353     5   0.65426  0.005965
# 8 2              4            0.63835  0.005303     2   0.65415  0.003323
# 6 3              3            0.63825  0.002333     2   0.64090  0.018526
# 8 2              3            0.63780  0.005091     2   0.64905  0.001485
#   4              4            0.63565  0.002899     2   0.65555  0.001909
#
#                              epoch_count
# ...
